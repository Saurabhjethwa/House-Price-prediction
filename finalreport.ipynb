# %%
import pandas as pd

import numpy as np

import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt

data = pd.read_csv("C:\\Users\\Polestar User\\Desktop\\train.csv") 
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
#Dividing dataset into Numerical and Categorical Features

#Numerical

numerical = data.select_dtypes(include = ['float64', 'int64'])
numerical.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1    ...      WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706    ...               0           61
# 1          1976         0.0         978    ...             298            0
# 2          2002       162.0         486    ...               0           42
# 3          1970         0.0         216    ...               0           35
# 4          2000       350.0         655    ...             192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# 0              0          0            0         0        0       2    2008
# 1              0          0            0         0        0       5    2007
# 2              0          0            0         0        0       9    2008
# 3            272          0            0         0        0       2    2006
# 4              0          0            0         0        0      12    2008
#
#    SalePrice
# 0     208500
# 1     181500
# 2     223500
# 3     140000
# 4     250000
#
# [5 rows x 38 columns]

# %%
# Categorical

category = data.select_dtypes(include = ['O'])
category.head()
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1      ...      GarageType GarageFinish GarageQual  \
# 0      CollgCr       Norm      ...          Attchd          RFn         TA
# 1      Veenker      Feedr      ...          Attchd          RFn         TA
# 2      CollgCr       Norm      ...          Attchd          RFn         TA
# 3      Crawfor       Norm      ...          Detchd          Unf         TA
# 4      NoRidge       Norm      ...          Attchd          RFn         TA
#
#   GarageCond PavedDrive PoolQC Fence MiscFeature SaleType SaleCondition
# 0         TA          Y    NaN   NaN         NaN       WD        Normal
# 1         TA          Y    NaN   NaN         NaN       WD        Normal
# 2         TA          Y    NaN   NaN         NaN       WD        Normal
# 3         TA          Y    NaN   NaN         NaN       WD       Abnorml
# 4         TA          Y    NaN   NaN         NaN       WD        Normal
#
# [5 rows x 43 columns]

# %%
# Plotting NA values of Categories

cat = category.isna().sum()
plt.style.use('ggplot')
cat.T.plot(kind='bar')

# %%
plt.scatter(data['PoolArea'],data['SalePrice'])

# %%
plt.scatter(data['MiscVal'],data['SalePrice'])

# %%
# Removing Features with High number of NA values

del category['PoolQC']
del category['Fence']
del category['MiscFeature']
del category['Alley']
del category['FireplaceQu']

# %%
# Plotting NA of Numerical

num=numerical.isna().sum()
plt.style.use('ggplot')
num.T.plot(kind='bar')

# %%
# Histogram for Numerical Data and distribution

numerical.hist(figsize=(16, 20), bins=100, xlabelsize=10, ylabelsize=10);

# %%
data['MoSold'].hist(bins=100)

# %%
data['YearBuilt'].hist(bins=100)

# %%
data['GarageYrBlt'].hist(bins=100)

# %%
data['GrLivArea'].hist(bins=100)

# %%
plt.scatter(data['GrLivArea'],data['SalePrice'])

# %%
plt.scatter(data['OverallQual'],data['SalePrice'])

# %%
data['OverallQual'].hist(bins=100)

# %%
data['TotalBsmtSF'].hist(bins=100)

# %%
plt.scatter(data['TotalBsmtSF'],data['SalePrice'])

# %%
data['GarageCars'].hist(bins=100)

# %%
category['MSSubClass'] = data['MSSubClass']
category['OverallQual'] = data['OverallQual']
category['OverallCond'] = data['OverallCond']
category['MoSold'] = data['MoSold']

# %%
category['OverallQual'] = category['OverallQual'].astype('category')
category['MSSubClass'] = category['MSSubClass'].astype('category')
category['OverallCond'] = category['OverallCond'].astype('category')
category['MoSold'] = category['MoSold'].astype('category')

# %%
# SalesPrice Distribution

sns.distplot(data['SalePrice'], color='r', bins=50);

# %%
# Categorical frequency table

fig, axes = plt.subplots(round(len(category.columns) / 4), 4, figsize=(12, 30))
for i, ax in enumerate(fig.axes):
    if i < len(category.columns):
        ax.set_xticklabels(ax.xaxis.get_majorticklabels(), rotation=90)
        sns.countplot(x=category.columns[i], alpha=0.7, data=category, ax=ax)
fig.tight_layout()

# %%
pd.crosstab(data['SaleType'],data['SaleCondition'])
# Out:
# SaleCondition  Abnorml  AdjLand  Alloca  Family  Normal  Partial
# SaleType
# COD                 24        0       0       0      19        0
# CWD                  1        0       0       1       2        0
# Con                  0        0       0       0       2        0
# ConLD                2        0       0       0       6        1
# ConLI                1        0       0       0       4        0
# ConLw                0        0       0       0       5        0
# New                  0        0       0       0       0      122
# Oth                  3        0       0       0       0        0
# WD                  70        4      12      19    1160        2

# %%
pd.crosstab(data['GarageQual'],data['GarageType'])
# Out:
# GarageType  2Types  Attchd  Basment  BuiltIn  CarPort  Detchd
# GarageQual
# Ex               0       0        0        0        0       3
# Fa               1       6        2        0        2      37
# Gd               0       9        0        1        0       4
# Po               0       0        0        0        0       3
# TA               5     855       17       87        7     340

# %%
pd.crosstab(data['Heating'],data['HeatingQC'])
# Out:
# HeatingQC   Ex  Fa   Gd  Po   TA
# Heating
# Floor        0   0    0   0    1
# GasA       739  34  239   1  415
# GasW         2   3    2   0   11
# Grav         0   7    0   0    0
# OthW         0   2    0   0    0
# Wall         0   3    0   0    1

# %%
pd.crosstab(data['BsmtQual'],data['BsmtCond'])
# Out:
# BsmtCond  Fa  Gd  Po   TA
# BsmtQual
# Ex         0  11   0  110
# Fa         8   0   2   25
# Gd         2  36   0  580
# TA        35  18   0  596

# %%
pd.crosstab(data['ExterQual'],data['ExterCond'])
# Out:
# ExterCond  Ex  Fa   Gd  Po   TA
# ExterQual
# Ex          1   0    3   0   48
# Fa          0   6    0   0    8
# Gd          0   0   35   0  453
# TA          2  22  108   1  773

# %%
pd.crosstab(data['BldgType'],data['HouseStyle'])
# Out:
# HouseStyle  1.5Fin  1.5Unf  1Story  2.5Fin  2.5Unf  2Story  SFoyer  SLvl
# BldgType
# 1Fam           142      13     607       7       9     362      20    60
# 2fmCon           8       1       7       1       2      11       0     1
# Duplex           4       0      29       0       0       9       9     1
# Twnhs            0       0       5       0       0      33       4     1
# TwnhsE           0       0      78       0       0      30       4     2

# %%
# Categorical Feature Reduction

cat_copy=category.copy()

del cat_copy['Street']
del cat_copy['Condition2']
del cat_copy['Utilities']
del cat_copy['RoofMatl']

# %%
# Correlation heatmap

abc2 = numerical.corr()

plt.figure(figsize = (20,10))
sns.heatmap(abc2[(abc2 >= 0.5) | (abc2 <= -0.4)], 
        xticklabels=abc2.columns,
        yticklabels=abc2.columns,linewidths=0.1)

# %%
#Correlation matrix

corr = numerical.corr()
corr.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col0 {
#             background-color:  #023858;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col1 {
#             background-color:  #c4cbe3;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col2 {
#             background-color:  #c9cee4;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col3 {
#             background-color:  #f1ebf5;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col4 {
#             background-color:  #ebe6f2;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col5 {
#             background-color:  #c5cce3;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col6 {
#             background-color:  #c9cee4;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col7 {
#             background-color:  #e8e4f0;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col8 {
#             background-color:  #f5eef6;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col9 {
#             background-color:  #b7c5df;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col10 {
#             background-color:  #e2dfee;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col11 {
#             background-color:  #b7c5df;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col12 {
#             background-color:  #e0dded;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col13 {
#             background-color:  #d9d8ea;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col14 {
#             background-color:  #e1dfed;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col15 {
#             background-color:  #ede8f3;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col16 {
#             background-color:  #f3edf5;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col17 {
#             background-color:  #c0c9e2;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col18 {
#             background-color:  #eee9f3;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col19 {
#             background-color:  #e3e0ee;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col20 {
#             background-color:  #eee9f3;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col21 {
#             background-color:  #e4e1ef;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col22 {
#             background-color:  #e5e1ef;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col23 {
#             background-color:  #f3edf5;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col24 {
#             background-color:  #f1ebf5;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col25 {
#             background-color:  #d2d2e7;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col26 {
#             background-color:  #e2dfee;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col27 {
#             background-color:  #e7e3f0;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col28 {
#             background-color:  #f2ecf5;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col29 {
#             background-color:  #f2ecf5;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col30 {
#             background-color:  #c6cce3;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col31 {
#             background-color:  #fff7fb;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col32 {
#             background-color:  #f4edf6;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col33 {
#             background-color:  #eee9f3;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col34 {
#             background-color:  #faf2f8;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col35 {
#             background-color:  #e7e3f0;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col36 {
#             background-color:  #ece7f2;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow0_col37 {
#             background-color:  #f0eaf4;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col0 {
#             background-color:  #f7f0f7;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col1 {
#             background-color:  #023858;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col2 {
#             background-color:  #fff7fb;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col3 {
#             background-color:  #fff7fb;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col4 {
#             background-color:  #e0dded;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col5 {
#             background-color:  #d5d5e8;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col6 {
#             background-color:  #c0c9e2;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col7 {
#             background-color:  #dcdaeb;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col8 {
#             background-color:  #eae6f1;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col9 {
#             background-color:  #c5cce3;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col10 {
#             background-color:  #ede8f3;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col11 {
#             background-color:  #d3d4e7;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col12 {
#             background-color:  #fff7fb;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col13 {
#             background-color:  #fff7fb;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col14 {
#             background-color:  #93b5d6;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col15 {
#             background-color:  #dddbec;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col16 {
#             background-color:  #e8e4f0;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col17 {
#             background-color:  #c0c9e2;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col18 {
#             background-color:  #ece7f2;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col19 {
#             background-color:  #c9cee4;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col20 {
#             background-color:  #cccfe5;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col21 {
#             background-color:  #eee9f3;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col22 {
#             background-color:  #9fbad9;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col23 {
#             background-color:  #f1ebf5;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col24 {
#             background-color:  #f5eef6;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col25 {
#             background-color:  #bcc7e1;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col26 {
#             background-color:  #ede7f2;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col27 {
#             background-color:  #f8f1f8;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col28 {
#             background-color:  #f0eaf4;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col29 {
#             background-color:  #f3edf5;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col30 {
#             background-color:  #c9cee4;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col31 {
#             background-color:  #fff7fb;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col32 {
#             background-color:  #f7f0f7;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col33 {
#             background-color:  #f5eff6;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col34 {
#             background-color:  #faf3f9;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col35 {
#             background-color:  #eee8f3;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col36 {
#             background-color:  #efe9f3;
#         }    #T_b5f4c352_b7ff_11e8_a207_305a3a46884arow1_col37 {
#             background-color:  #f8f1f8;
#         }    #T_b5f4c35

# %%
# removing numerical after checking heatmap

num_copy=numerical.copy()

del num_copy['BsmtUnfSF']
del num_copy['TotalBsmtSF']
del num_copy['GarageYrBlt']
del num_copy['TotRmsAbvGrd']
del num_copy['GarageArea']
del num_copy['2ndFlrSF']
del num_copy['BsmtFullBath']
#del num_copy['FullBath']
del num_copy['1stFlrSF']
del num_copy['BedroomAbvGr']

# %%
# removing numerical after checking scatter plot

del num_copy['Id']
del num_copy['LowQualFinSF']
del num_copy['BsmtFinSF2']
del num_copy['PoolArea']
del num_copy['MiscVal']
del num_copy['YrSold']
del num_copy['BsmtHalfBath']
del num_copy['Fireplaces']

# %%
del num_copy['MSSubClass']
del num_copy['OverallQual']
del num_copy['OverallCond']
del num_copy['MoSold']

# %%
# feature engineering

num_copy['YearSold']=data['YrSold']
num_copy['YearDiff']=num_copy['YearSold'] - num_copy['YearBuilt']

del num_copy['YearSold']
del num_copy['YearBuilt']


import numpy as np

x=num_copy['YearDiff']
y=num_copy['SalePrice']

plt.scatter(x, y)

z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"b--")

plt.show()

# %%
##

x=num_copy['YearRemodAdd']
y=num_copy['SalePrice']

plt.scatter(x, y)

z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"b--")

plt.show()


del num_copy['YearRemodAdd']

# %%
##

del num_copy['3SsnPorch']

num_copy['Porch'] =  (num_copy['OpenPorchSF']+num_copy['EnclosedPorch']+num_copy['ScreenPorch'])/3

plt.scatter(num_copy['Porch'], num_copy['SalePrice'])


del num_copy['OpenPorchSF']
del num_copy['EnclosedPorch']
del num_copy['ScreenPorch']

# %%
num_copy['FullBath'] = data['FullBath']

num_copy['Bath']=num_copy['FullBath']+num_copy['HalfBath']

del num_copy['FullBath']
del num_copy['HalfBath']

# %%
#removing MasVnrArea because distribution between woodeck and masnvarea is same 

del num_copy['MasVnrArea']
